# %% [markdown]
# ## Project Description

# %%
Congratulations! You have completed the SQL course. It's time to apply the knowledge and skills you've gained to a project: a real-life analytical case study that you will complete on your own.

When you finish the project, submit your work to the project reviewer for evaluation. They will give you feedback within 48 hours. Use the feedback to make changes and then submit the new version back to the project reviewer.

You can get more feedback on the new version. This is completely normal. It's not uncommon to go through multiple feedback and review cycles.

Your project will be considered complete once the project reviewer approves it.

Project Description
You are working as an analyst for Zuber, a new ride-sharing company launching in Chicago. Your task is to find patterns in the available information. You want to understand passenger preferences and the impact of external factors on rides.

Working with a database, you will analyze competitor data and test a hypothesis about the impact of weather on travel frequency.

Data description
A database with information about taxi rides in Chicago:

Table neighborhoods: Data on the city's neighborhoods

name: neighborhood name
neighborhood_id: neighborhood code
Table cabs: Data on taxis

cab_idvehicle code
vehicle_idThe vehicle's technical identification.
company_namethe company that owns the vehicle
Table trips: Data on races

trip_idrace code
cab_id: vehicle code for the vehicle operating the ride
start_tsDate and time of the race start (time rounded to the nearest hour)
end_ts: date and time of the end of the race (time rounded to the nearest hour)
duration_seconds: race duration in seconds
distance_miles: distance traveled in miles
pickup_location_id: pickup neighborhood code
dropoff_location_idDelivery neighborhood code
Table weather_records: Climate data

record_id: meteorological record code
tsRecords date and time (time rounded to the nearest hour)
temperaturetemperature when the recording was made
description: brief description of weather conditions, e.g., "light rain" or "scattered clouds"

# %%
Table layout

# %%
Note: There is no direct connection between the tables trips in weather_recordsthe database. But you can still use JOIN and join them using the time the ride started ( trips.start_ts) and the time the time record was made ( weather_records.ts).

Instructions for completing the project.

Step 1. Write code to analyze the weather data for Chicago in November 2017 on the website:

https://practicum-content.s3.us-west-1.amazonaws.com/data-analyst-eng/moved_chicago_weather_2017.html

Step 2. Exploratory Data Analysis

Find the number of taxi rides for each taxi company from November 15th to 16th, 2017. Name the resulting field trips_amountand print it along with the field company_name. Sort the results by the field trips_amountin descending order.
Find the number of rides for each taxi company whose name contains the words "Yellow" or "Blue" from November 1st to 7th, 2017. Name the resulting variable trips_amount. Group the results by the field company_name.
In November 2017, the most popular taxi companies were Flash Cab and Taxi Affiliation Services. Find the number of rides for these two companies and name the resulting variable trips_amount. Group the rides for all other companies into the "Other" group. Group the data by taxi company names. Name the field with the taxi company names company. Sort the result in descending order by trips_amount.
Step 3. Test the hypothesis that the duration of Loop runs to O'Hare International Airport changes on rainy Saturdays.

Retrieve the identifiers for the O'Hare and Loop neighborhoods from the table neighborhoods.
For each hour, retrieve the weather condition records from the table weather_records. Using the CASE operator, divide all hours into two groups: "Bad" if the field descriptioncontains the words "rain" or "storm" and "Good" for others. Name the resulting field weather_conditions. The final table should include two fields: date and time ( ts ) and weather_conditions.
Retrieve from the table tripsall races that started at the Loop ( neighborhood_id: 50) and finished at O'Hare ( neighborhood_id: 63) on a Saturday. Obtain the weather conditions for each race. Use the method you applied in the previous task. Also retrieve the duration of each race. Ignore races for which weather data is not available.
Step 4. Exploratory data analysis (Python)

In addition to the data retrieved in the previous tasks, you received a second file. You now have these two CSVs:

project_sql_result_01.csvIt contains the following data:

company_name: name of the taxi company
trips_amountThe number of rides for each taxi company from November 15th to 16th, 2017.
project_sql_result_04.csvIt contains the following data:

dropoff_location_nameChicago neighborhoods where the races ended
average_tripsThe average number of trips that ended in each neighborhood in November 2017.
For these two datasets, you now need to:

import the files
study the data they contain
Check that the data types are correct.
Identify the top 10 neighborhoods in terms of destinations.
Create graphs: taxi companies and number of rides, top 10 neighborhoods by number of rides where that neighborhood is the destination.
Draw conclusions based on each graph and explain the results.
Step 5. Testing hypotheses (Python)

project_sql_result_07.csv—The result of the last query. It contains data about Loop trips to O'Hare International Airport. Remember, these are the values ​​for the table fields:

start_ts— date and time the race starts
weather_conditions— weather conditions at the time the race started
duration_seconds— travel time in seconds
Test the hypothesis: "The average duration of Loop trips to O'Hare International Airport changes on rainy Saturdays."

Determine the significance level (alpha) value yourself.

Explain:

How did you form the null and alternative hypotheses?
What criteria did you use to test the hypothesis and why?
How will my project be evaluated?
Here are the project evaluation criteria. Read them carefully before you begin work.

Here's what the project reviewer will look for when evaluating your project:

How do you retrieve data from the website?
How do you slice data?
How do you group the data?
if you use the correct methods to join tables
How do you formulate hypotheses?
What criteria do you use to test the hypotheses and why?
What conclusions do you reach?
if you leave comments at every step
The conclusion sheets and summaries from previous lessons have everything you need to complete the project.
